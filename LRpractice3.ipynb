# %% [markdown]
# **simple Linear Regression**

# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Import Dataset**

# %%
db=pd.read_csv("weight-height.csv")
x=db.iloc[:,:-1].values
y=db.iloc[:,-1].values

# %%
print(x)
# Out:
# [['Male' 73.847017017515]
#  ['Male' 68.7819040458903]
#  ['Male' 74.1101053917849]
#  ...
#  ['Female' 63.8679922137577]
#  ['Female' 69.0342431307346]
#  ['Female' 61.9442458795172]]

# %%
print(y)
# Out:
# [241.89356318 162.31047252 212.74085556 ... 128.47531878 163.85246135
#  113.64910268]

# %% [markdown]
# **Encoding Independent varaibles**

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

en=ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[0])],remainder="passthrough")
x=en.fit_transform(x)

# %%
print(x)
# Out:
# [[0.0 1.0 73.847017017515]
#  [0.0 1.0 68.7819040458903]
#  [0.0 1.0 74.1101053917849]
#  ...
#  [1.0 0.0 63.8679922137577]
#  [1.0 0.0 69.0342431307346]
#  [1.0 0.0 61.9442458795172]]

# %% [markdown]
# **Split the dataset into training and test sets**

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x[:,2:],y,test_size=0.2,random_state=1)

# %% [markdown]
# Training the Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **visualizing trainset results**

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,regression.predict(x_train),color="blue")
plt.title("height-weight")
plt.xlabel("height")
plt.ylabel("weight")
plt.show()

# %% [markdown]
# **Visualizing test results**

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_train,regression.predict(x_train),color="blue")
plt.title("height-weight")
plt.xlabel("height")
plt.ylabel("weight")
plt.show()
